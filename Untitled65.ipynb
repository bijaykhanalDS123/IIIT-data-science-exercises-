# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df[~(df.isna())].describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
100*(df.isna().sum()/len(df))
# Out:
# male               0.000000
# age                0.000000
# education          2.477584
# currentSmoker      0.000000
# cigsPerDay         0.684285
# BPMeds             1.250590
# prevalentStroke    0.000000
# prevalentHyp       0.000000
# diabetes           0.000000
# totChol            1.179802
# sysBP              0.000000
# diaBP              0.000000
# BMI                0.448325
# heartRate          0.023596
# glucose            9.155262
# TenYearCHD         0.000000
# dtype: float64

# %%
len(df.columns[df.isna().any()]), len(df.columns)
# Out:
# (7, 16)

# %%
df.drop(df.loc[:, ((((df.isna().sum()/len(df))*100))>=40)], axis = 1, inplace = True)

# %%
df.isna().sum().sum()
# Out:
# 645

# %%
0.4*645
# Out:
# 258.0

# %%
# Continuous: age, trestbps, chol, thalac, oldpeak

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
df.education.unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
df.isna().any(axis = 0).sum()
# Out:
# 7

# %%
df[df.isna().any(axis = 1)].shape
# Out:
# (582, 16)

# %%
# plt.figure(figsize = [10,55])

fig = plt.figure(figsize = (15,20))
ax = fig.gca() #retrieves the current axes for the given figure
df.hist(ax = ax);

# %%
df.corr()
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.028979   0.017352       0.197596    0.317930
# age             -0.028979  1.000000  -0.165883      -0.213748   -0.192791
# education        0.017352 -0.165883   1.000000       0.018532    0.008085
# currentSmoker    0.197596 -0.213748   0.018532       1.000000    0.769690
# cigsPerDay       0.317930 -0.192791   0.008085       0.769690    1.000000
# BPMeds          -0.052506  0.122995  -0.010815      -0.048938   -0.046134
# prevalentStroke -0.004546  0.057655  -0.035112      -0.032988   -0.032707
# prevalentHyp     0.005313  0.307194  -0.081970      -0.103260   -0.066146
# diabetes         0.015708  0.101258  -0.038680      -0.044295   -0.037067
# totChol         -0.070322  0.262131  -0.023115      -0.046562   -0.026320
# sysBP           -0.035989  0.394302  -0.129631      -0.130230   -0.088780
# diaBP            0.057933  0.206104  -0.062316      -0.107746   -0.056632
# ...

# %%
plt.figure(figsize=[20,12])

sns.set()
sns.heatmap(df.corr(), cmap='RdYlGn', annot = True)
;
# Out:
# ''

# %%
# Since 'Glucose' has a high null value percentage (9.15%), lets consider deleting rows with missing values in this column. 

df = df[~(df.glucose.isna())]
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.education.fillna(df.education.describe().median(), inplace = True)

# %%
df.education.isna().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  3850.000000  3850.000000  3850.000000    3850.000000  3825.000000
# mean      0.442597    49.643896    13.790613       0.490649     8.978301
# std       0.496759     8.596204    73.500479       0.499977    11.912086
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    57.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000   470.874854       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3799.000000      3850.000000   3850.000000  3850.000000  3840.000000
# mean      0.030008         0.006234      0.312727     0.027273   237.001302
# std       0.170631         0.078718      0.463664     0.162898    44.770972
# ...

# %%
df[[ 'cigsPerDay', 'totChol', 'BMI', 'heartRate']].mean()
# Out:
# cigsPerDay      8.978301
# totChol       237.001302
# BMI            25.810420
# heartRate      75.733437
# dtype: float64

# %%
df[[ 'cigsPerDay', 'totChol', 'BMI', 'heartRate']].mean()
# Out:
# cigsPerDay      8.978301
# totChol       237.001302
# BMI            25.810420
# heartRate      75.733437
# dtype: float64

# %%
values = {'cigsPerDay': df.cigsPerDay.mean(), 'totChol':df.totChol.mean(),'BMI':df.BMI.mean(),'heartRate':df.heartRate.mean()}
df[[ 'cigsPerDay', 'totChol', 'BMI', 'heartRate']] = df[[ 'cigsPerDay', 'totChol', 'BMI', 'heartRate']].isna().fillna(values)

# %%
df[[ 'cigsPerDay', 'totChol', 'BMI', 'heartRate']].isna().sum()
# Out:
# cigsPerDay    0
# totChol       0
# BMI           0
# heartRate     0
# dtype: int64

# %%
df.education.fillna(df.education.median(), inplace = True)

# %%
df.education.isna().sum()
# Out:
# 0

# %%
df.BPMeds.unique()
# Out:
# array([ 0.,  1., nan])

# %%
df.BPMeds.value_counts()
# Out:
# 0.0    3685
# 1.0     114
# Name: BPMeds, dtype: int64

# %%
values = {'BPMeds': df.BPMeds.mode()[0], 'prevalentStroke': df.prevalentStroke.mode()[0], 'prevalentHyp': df.prevalentHyp.mode()[0], 'diabetes': df.diabetes.mode()[0], 'sysBP':df.sysBP.mode()[0], 'diaBP':df.diaBP.mode()[0]}
df[['BPMeds', 'prevalentStroke','prevalentHyp', 'diabetes', 'sysBP', 'diaBP']] = df[['BPMeds', 'prevalentStroke','prevalentHyp', 'diabetes', 'sysBP', 'diaBP']].fillna(values)
df.isna().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')

# %%
df.columns[~(df[['glucose', 'male']])]
# imputer.fit_transform(df.columns[~df[['male', 'glucose']]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6728/712757503.py in <module>
# ----> 1 df.columns[~(df[['glucose', 'male']])]
#       2 # imputer.fit_transform(df.columns[~df[['male', 'glucose']]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1530             return self
#    1531
# -> 1532         new_data = self._mgr.apply(operator.invert)
#    1533         return self._constructor(new_data).__finalize__(self, method="__invert__")
#    1534
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     323             try:
#     324                 if callable(f):
# --> 325                     applied = b.apply(f, **kwargs)
#     326                 else:
# ...
