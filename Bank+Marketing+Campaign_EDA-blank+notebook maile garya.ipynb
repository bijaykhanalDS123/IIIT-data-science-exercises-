# %% [markdown]
# ## Bank Telemarketing Campaign Case Study.

# %% [markdown]
# In this case study you’ll be learning Exploratory Data Analytics with the help of a case study on "Bank marketing campaign". This will enable you to understand why EDA is a most important step in the process of Machine Learning.

# %% [markdown]
# #### Problem Statement:

# %% [markdown]
#
#
# The bank provides financial services/products such as savings accounts, current accounts, debit cards, etc. to its customers. In order to increase its overall revenue, the bank conducts various marketing campaigns for its financial products such as credit cards, term deposits, loans, etc. These campaigns are intended for the bank’s existing customers. However, the marketing campaigns need to be cost-efficient so that the bank not only increases their overall revenues but also the total profit. You need to apply your knowledge of EDA on the given dataset to analyse the patterns and provide inferences/solutions for the future marketing campaign.
#
# The bank conducted a telemarketing campaign for one of its financial products ‘Term Deposits’ to help foster long-term relationships with existing customers. The dataset contains information about all the customers who were contacted during a particular year to open term deposit accounts.
#
#
# **What is the term Deposit?**
#
# Term deposits also called fixed deposits, are the cash investments made for a specific time period ranging from 1 month to 5 years for predetermined fixed interest rates. The fixed interest rates offered for term deposits are higher than the regular interest rates for savings accounts. The customers receive the total amount (investment plus the interest) at the end of the maturity period. Also, the money can only be withdrawn at the end of the maturity period. Withdrawing money before that will result in an added penalty associated, and the customer will not receive any interest returns.
#
# Your target is to do end to end EDA on this bank telemarketing campaign data set to infer knowledge that where bank has to put more effort to improve it's positive response rate.

# %%
# Outline:
# A. Attribute Descriptions
# I. Bank client data
# II. Related with the last contact of the current campaign
# III. Other attributes

# B. Structuring the data:
# I. Overall Analysis of the Data
# II. Data Structuring and Conversions

# C. Exploratory Data Analysis (EDA)
# I. Accepted vs Rejected Term Deposits
# II. Distribution Plots

# D. Different Aspects of the Analysis:
# I. Months of Marketing Activty
# II. Seasonalities
# III. Number of Calls to the potential client
# IV. Age of the Potential Clients
# V. Types of Occupations that leads to more term deposits suscriptions

# E. Correlations that impacted the decision of Potential Clients. I. Analysis of our Correlation Matrix
# II. Balance Categories vs Housing Loans
# III. Negative Relationship between H.Loans and Term Deposits

# F. Classification Model
# I. Introduction
# II. Stratified Sampling
# III. Classification Models
# IV. Confusion Matrix
# V. Precision and Recall Curve
# VI. Feature Importances Decision Tree C.

# G. Next Campaign Strategy
# I. Actions the Bank should Consider

# A. Attributes Description:
# Input variables:

# Ai. bank client data:
# 1 - age: (numeric)
# 2 - job: type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital: marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education: (categorical: primary, secondary, tertiary and unknown)
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
# 8 - balance: Balance of the individual.

# Aii. Related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.

# Aiii. other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')

# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %% [markdown]
# #### Importing the libraries.

# %%
#import the warnings.

import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
#import the useful libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# irregularities:
#     missing values
#     incorrect format
#     incorrect headers

# Though data cleaning is often done in a somewhat haphazard manner, and it is difficult to define a ‘single structured process’
# you will study data cleaning through the following steps:

# Identifying the data types

# Fixing the rows and columns

# Imputing/removing missing values

# Handling outliers

# Standardising the values

# Fixing invalid values

# Filtering the data

# %%
# Fixing rows and columns:

#     delete incorrect rows
#         header rows
#         footer rows: page numbers

#     delete summary rows: constituency's total number of votes, total total number of voters that voted in the entire election

#     delete extra rows: column number indicator rows, blank rows, rows which indicate the start of a new section


# add column names if missing: names might be missing header rows which you might have to add

# rename columns consistently: name the column names if they are encoded and
# if there are abbreviations then you need to convert it to a clearer name  

# delete unnecessary columns: if the dataset fits on screen then it makes sense, columns might not likely be used so delete those
    
# split columns for more data: euta column lai split garnuparne ni hunsak6, jastai date bata year matrai niskalne
#     ani arko naya column year vanne ma halne, url cha vane hosst extract garne, address cha vane country extract garne, 
#     product hierarchy cha vane product category extract garne

# merge columns for identifiers: columns haru merge garne taki uniquely identifers create garna mil6
#     district       state           combined
#    ----------------------------------------------------------
#     aurangbad      Gujarat         aurangabad, gujarat
#     aurangbad      Maharaastra     aurangabad, maharastra

# aligned misaligned columns: shifted columns
    
#     euta value shift vaera last column ko bahira hun6
#     so testo bela ma tyo shifted vako column lai error vanera column name diera ani fixx garera align garne

# %%
# Impute/Removing missing values

# set values as missing values: kati values khali hun6 but tiniharu string hun6, katti missign values
#     haru ma XXX hun6, kati missing values ma 999 hun6 jaba ki column values ko range 10 samma ho,etc
    
# standard approcah: replae missing values with other values,
#     like 0 or average/median value le replace garne ya aru kunai value le replace garne 
    
# like the created date is missing
# so lets take the last updated date as the value to replace

# like i dont know the capital i can google and fill it in

# arko database bata lera ni fill garna mil6

# when i take data from an external source that a good way because it adds information

# when in take data from some other columns  im using an information from another column and putting it
# in the empty place

# when it fill it with 0 im eggagerating it im making an assumption when students in an exam are absent
# they scored 0 which is wrong
# so yo thik haina, so yestari arko column ko inof halne wrong ho idea
# missing values lai choddine , yadi avrage linupare tei missing value jasto hos testai ma average line
# comptaion garnu pare garne with those missing values included
# if you want to compute the correlation then compute them with those missing values

# tara yadi yetti dherai missing values chan jasle distorting the data analysig then we should remove
# the missing values
# if an entire row or column has missing values get rid of it
# if all the column which you are interesetd in are the same then get rid of those
# if all the rows have the same values then get rid of those

# time zone is missing
# i have the time as 5:45 in which time zone 
# i have the year as 21 is it 1921 or 2021 more likely
# birthdate is 01 is it 2021 or 1921, it may be 2021
    
    
# Following is a list of the major takeaways from the video.

# Types of missing values:

# MCAR: It stands for Missing completely at random. The reason behind the missing value is not
#     dependent on any other features. not dependent on anything.missing without any logic.
# MAR: It stands for Missing at random. The reason behind the missing value may be associated with
#     some other features. some dependent on other feature. can be dependent on other values of other 
#       columns values in the dataset.
# MNAR: It stands for Missing not at random. There is a specific reason behind the missing value.
#       like not revealing salary, age

# we need to understand why it is missing before we handle the missing values
# kina mising vayo chai thapaunuparr6
# suppose ecommerce data set cha users ko, jun ma revenue gerneeated vanne column cha
# aba kati users le ta transaction nai gareko hunna tesaile garda missing vayo vanna mil6

# %% [markdown]
# ## Session- 2, Data Cleaning

# %% [markdown]
# ### Segment- 2, Data Types

# %% [markdown]
# There are multiple types of data types available in the data set. some of them are numerical type and some of categorical type. You are required to get the idea about the data types after reading the data frame.
#
# Following are the some of the types of variables:
# - **Numeric data type**: banking dataset: salary, balance, duration and age.
# - **Categorical data type**: banking dataset: education, job, marital, poutcome and month etc.
# - **Ordinal data type**: banking dataset: Age group. jastai 20-30 gae rannge is lower than 50-60
# - **Time and date type**
# - **Coordinates type of data**: latitude and longitude type.

# %% [markdown]
# #### Read in the Data set.

# %%
#read the data set of "bank telemarketing campaign" in inp0.

inp0= pd.read_csv('bank_marketing_updated_v1.csv')

# %%
#Print the head of the data frame.

inp0.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#            jobs  education
# 0    management   tertiary
# 1    technician  secondary
# ...

# %% [markdown]
# ### Segment- 3, Fixing the Rows and Columns

# %% [markdown]
# Checklist for fixing rows:
# - **Delete summary rows**: Total and Subtotal rows
# - **Delete incorrect rows**: Header row and footer row
# - **Delete extra rows**: Column number, indicators, Blank rows, Page No.
#
# Checklist for fixing columns:
# - **Merge columns for creating unique identifiers**, if needed, for example, merge the columns State and City into the column Full address.
# - **Split columns to get more data**: Split the Address column to get State and City columns to analyse each separately.
# - **Add column names**: Add column names if missing.
# - **Rename columns consistently**: Abbreviations, encoded columns.
# - **Delete columns**: Delete unnecessary columns.
# - **Align misaligned columns**: The data set may have shifted columns, which you need to align correctly.

# %% [markdown]
# #### Read the file without unnecessary headers.

# %%
#read the file in inp0 without first two rows as it is of no use.

inp0= pd.read_csv('bank_marketing_updated_v1.csv', skiprows = 2)

# %%
#print the head of the data frame.

inp0
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
#print the information of variables to check their data types.

inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %%
#convert the age variable data type from float to integer.

# inp0 = inp0[~(inp0['age'].isna())]
inp0['age'] = inp0['age'].astype(int)



# inp0.info()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11380/3805168290.py in <module>
#       2
#       3 # inp0 = inp0[~(inp0['age'].isna())]
# ----> 4 inp0['age'] = inp0['age'].astype(int)
#       5
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
inp0.age.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Name: age, Length: 45211, dtype: bool

# %%
#print the average age of customers.
inp0['age'].mean()
# Out:
# 40.93565090394105

# %% [markdown]
# #### Dropping customer id column.

# %%
inp0.age.isnull().sum()
# Out:
# 20

# %%
#drop the customer id as it is of no use.

# inp0[~(inp0['customerid'])] # yo garna mildaina kinaki == some condition garnai par6, ki ta .drop nai use garnuparyo
inp0.drop('customerid', axis = 1, inplace = True)
# inp0 = inp0[inp0.columns[~(inp0.columns == 'customerid')]]
inp0.head(0)
# Out:
# Empty DataFrame
# Columns: [age, salary, balance, marital, jobedu, targeted, default, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, response]
# Index: []

# %% [markdown]
# #### Dividing "jobedu" column into job and education categories.

# %%
inp0['jobedu'].str.split(',').dtype # str nai ho
# Out:
# dtype('O')

# %%
#Extract job in newly created 'job' column from "jobedu" column.

# inp0['job'] = inp0['jobedu'].str.split(',').str[0]
# inp0

inp0['jobs'] = inp0['jobedu'].apply(lambda x: x.split(',')[0])
inp0
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
#Extract education in newly created 'education' column from "jobedu" column.

# inp0['education'] = inp0['jobedu'].str.split(',').str[1]
# inp0.head(0)

inp0['education'] = inp0['jobedu'].apply(lambda x: x.split(',')[1])
inp0
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
inp0.columns
# Out:
# Index(['age', 'salary', 'balance', 'marital', 'jobedu', 'targeted', 'default',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'response', 'jobs', 'education'],
#       dtype='object')

# %%
#drop the "jobedu" column from the dataframe.

# inp0 = inp0[inp0.columns[~(inp0.columns == 'jobedu')]]
# inp0

inp0.drop('jobedu', axis =1, inplace = True)
inp0
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %% [markdown]
# ### Segment- 4, Impute/Remove missing values

# %% [markdown]
# Take aways from the lecture on missing values:
#
# - **Set values as missing values**: Identify values that indicate missing data, for example, treat blank strings, "NA", "XX", "999", etc., as missing.
# - **Adding is good, exaggerating is bad**: You should try to get information from reliable external sources as much as possible, but if you can’t, then it is better to retain missing values rather than exaggerating the existing rows/columns.
# - **Delete rows and columns**: Rows can be deleted if the number of missing values is insignificant, as this would not impact the overall analysis results. Columns can be removed if the missing values are quite significant in number.
# - **Fill partial missing values using business judgement**: Such values include missing time zone, century, etc. These values can be identified easily.
#
# Types of missing values:
# - **MCAR**: It stands for Missing completely at random (the reason behind the missing value is not dependent on any other feature).
# - **MAR**: It stands for Missing at random (the reason behind the missing value may be associated with some other features).
# - **MNAR**: It stands for Missing not at random (there is a specific reason behind the missing value).

# %% [markdown]
# #### handling missing values in age column.

# %%
#count the missing values in age column.

# inp0[inp0['age'].isna() == False]
inp0['age'].value_counts()
inp0['age'].sum()
inp0['age'].unique()
# len(inp0['age'].unique())
# inp0.info()
# Out:
# array([58., 44., 33., 47., 35., 28., 42., 43., 41., 29., 53., 57., 51.,
#        45., 60., 56., 32., 25., 40., 39., 52., 46., 36., 49., 59., 37.,
#        50., 54., 55., 48., 24., 38., 31., 30., 27., 34., 23., 26., nan,
#        61., 22., 21., 20., 66., 62., 83., 75., 67., 70., 65., 68., 64.,
#        69., 72., 71., 19., 76., 85., 63., 90., 82., 73., 74., 78., 80.,
#        94., 79., 77., 86., 95., 81., 18., 89., 84., 87., 92., 93., 88.])

# %%
inp0['age'].isnull().sum()
inp0.isna().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# jobs          0
# education     0
# dtype: int64

# %%
#pring the shape of dataframe inp0

inp0.shape
# inp0.info()
# Out:
# (45211, 19)

# %%
#calculate the percentage of missing values in age column.

100*(len(inp0[inp0['age'].isna()])/len(inp0.age))
# Out:
# 0.0442370219636814

# %% [markdown]
# Drop the records with age missing.

# %%
#drop the records with age missing in inp0 and copy in inp1 dataframe.

inp1 = inp0[~(inp0.age.isna()) ]
inp1.isna().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# jobs          0
# education     0
# dtype: int64

# %% [markdown]
# #### handling missing values in month column

# %%
# Imputation on categorical/numeric columns:

# Categorical column: 

# Impute the most popular category.

# Imputation can be done using logistic regression techniques.

# Numerical column:

# Impute the missing value with mean/median/mode.

# The other methods to impute the missing values involve the use of interpolation, linear regression.
# These methods are useful for continuous numerical variables.

# %%
#count the missing values in month column in inp1.

inp1.month.isna().sum()
# Out:
# 50

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45191 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45191 non-null  float64
#  1   salary     45191 non-null  int64
#  2   balance    45191 non-null  int64
#  3   marital    45191 non-null  object
#  4   targeted   45191 non-null  object
#  5   default    45191 non-null  object
#  6   housing    45191 non-null  object
#  7   loan       45191 non-null  object
#  8   contact    45191 non-null  object
#  9   day        45191 non-null  int64
#  10  month      45141 non-null  object
#  11  duration   45191 non-null  object
#  12  campaign   45191 non-null  int64
#  13  pdays      45191 non-null  int64
#  14  previous   45191 non-null  int64
#  15  poutcome   45191 non-null  object
#  16  response   45161 non-null  object
#  17  jobs       45191 non-null  object
#  18  education  45191 non-null  object
# ...

# %%
#print the percentage of each month in the data frame inp1.

inp1.month.value_counts(normalize = True)
# Out:
# may, 2017    0.304380
# jul, 2017    0.152522
# aug, 2017    0.138123
# jun, 2017    0.118141
# nov, 2017    0.087880
# apr, 2017    0.064908
# feb, 2017    0.058616
# jan, 2017    0.031058
# oct, 2017    0.016327
# sep, 2017    0.012760
# mar, 2017    0.010545
# dec, 2017    0.004741
# Name: month, dtype: float64

# %%
#find the mode of month in inp1

inp1.month.mode()
month_mode = inp1.month.mode()[0]
month_mode
# Out:
# 'may, 2017'

# %%
# fill the missing values with mode value of month in inp1.

inp1.month.fillna(month_mode, inplace = True)

# %%
#let's see the null values in the month column.
inp1.month.isna().sum()
# Out:
# 0

# %%
inp1.month.value_counts(normalize = True)
# Out:
# may, 2017    0.305149
# jul, 2017    0.152353
# aug, 2017    0.137970
# jun, 2017    0.118010
# nov, 2017    0.087783
# apr, 2017    0.064836
# feb, 2017    0.058551
# jan, 2017    0.031024
# oct, 2017    0.016309
# sep, 2017    0.012746
# mar, 2017    0.010533
# dec, 2017    0.004735
# Name: month, dtype: float64

# %% [markdown]
# #### handling missing values in response column

# %%
#count the missing values in response column in inp1.

inp1.response.isna().sum()
# Out:
# 30

# %%
inp1.describe()
# Out:
#                 age         salary        balance           day      campaign  \
# count  45191.000000   45191.000000   45191.000000  45191.000000  45191.000000
# mean      40.935651   57005.974641    1362.432520     15.806289      2.763847
# std       10.619198   32084.253154    3045.120417      8.322311      3.098407
# min       18.000000       0.000000   -8019.000000      1.000000      1.000000
# 25%       33.000000   20000.000000      72.000000      8.000000      1.000000
# 50%       39.000000   60000.000000     448.000000     16.000000      2.000000
# 75%       48.000000   70000.000000    1428.000000     21.000000      3.000000
# max       95.000000  120000.000000  102127.000000     31.000000     63.000000
#
#               pdays      previous
# count  45191.000000  45191.000000
# mean      40.181253      0.579983
# std      100.074099      2.303017
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
type(inp1.shape[0])
# Out:
# int

# %%
#calculate the percentage of missing values in response column. 

# inp1.response.value_counts(normalize = True)
100*(inp1.response.isna().sum()/inp1.shape[0])
# Out:
# 0.06638489964816004

# %%
# What do you think about the treatment of missing values in the response column?

# They can be removed because they are very small in number as compared to entries in the dataset.

# %% [markdown]
# Target variable is better of not imputed.
# - Drop the records with missing values.

# %%
#drop the records with response missings in inp1.

inp1 = inp1[~(inp1.response.isna())]
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
#calculate the missing values in each column of data frame: inp1.

inp1.isna().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# jobs         0
# education    0
# dtype: int64

# %% [markdown]
# #### handling pdays column.

# %%
#describe the pdays column of inp1.

inp1.pdays.describe()
# Out:
# count    45161.000000
# mean        40.182015
# std        100.079372
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %% [markdown]
# -1 indicates the missing values.
# Missing value does not always be present as null.
# How to handle it:
#
# Objective is:
# - you should ignore the missing values in the calculations
# - simply make it missing - replace -1 with NaN.
# - all summary statistics- mean, median etc. we will ignore the missing values of pdays.

# %%
#describe the pdays column with considering the -1 values.
# inp1.loc[inp1.pdays<0] = np.NaN #replaces the entire row with NaN if 'pdays' is less than 0
inp1.loc[inp1.pdays<0, 'pdays'] = np.NaN # replaces the rows of pdays column with NaN if 'pdays' is less than 0
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
inp1.pdays.describe()

# There are 8246 non-null values (entries that have a value) in the 'pdays' column.
# The average (mean) value is approximately 224.54.
# The values in the 'pdays' column spread out around the mean by about 115.21 on average.
# The smallest (minimum) value is 1, and the largest (maximum) value is 871.
# About 25% of the values are less than or equal to 133.
# About 50% of the values are less than or equal to 195 (the median).
# About 75% of the values are less than or equal to 327.
# Out:
# count    8246.000000
# mean      224.542202
# std       115.210792
# min         1.000000
# 25%       133.000000
# 50%       195.000000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
# Missing values doesnt have to always be null, yeha -1 rakhyathyo kinavane tyo days haruko data navaera
# so tesaile -1 indicates 'no data'
# tesailai hamile Nan le replace garya

# %% [markdown]
# ### Segment- 5, Handling Outliers

# %% [markdown]
# Major approaches to the treat outliers:
#
# - **Imputation**
# - **Deletion of outliers**
# - **Binning of values**
# - **Cap the outlier**

# %%
# cause of outliers
# investigate the cause
# coding error ho ki vanera herne
# age ma 7000 vayo vane ta error nai hola
# tesaile understanding the data nai garnupar6

# it may have some meaning
# like in ages of patients in a hospital
# ages are typically between 0-60
# 90 cha re
# yo ta valid value ho
# it makes sense and its not an error
# lets say there is a value which is -3
# it may seem nonsensical
# tara delivery hunu vanda agadiko time lai -ve le janako ni hunasak6
# then it does make sense
# tesaile cause k ho tahapaune

# aba handle kaari garne outliers?

# imputation the outlier
# if values are detached from the main body
# there is no logic over here
# its just random errors encoding errors
# that otliers is as good as no information
# in this case you can think of the outlier as missing information missing value
# ra teso ho vane hamile jun pani tarika use garna mil6 when handling missing values like imputaion method

# delete the outliers
# jastai aba bill gates ayo room ma ani employees ko avg salary nikalda ta sabaijana millionaire hun6n
# testo bela ma ta delete garnupar6

# binning the values
# yadi chunk of values which are extradoniary high/low cha re
# testo bela ma binning garne into high value range/mid value range/low value range
# in this way we are identifying them as valid values but these are just high values

# capping the outliers
# suppose those values are high and are expected and we donot want to lose them
# wherever the value is high we cap to a reasonable upper limit so that we use that point 
# there might be ways to get to the upper limit lets say i want to get to the 99th percentile, 95th percentile
# essentially whatever you understand the data is the reasonable cap for the value

# detecting ouliers is by the use of 2 key boxplot
# it depends on the quartiles and the expected spread of the valuues
# if these values are way beyond my expected values then it is an outlier

# %% [markdown]
# #### Age variable

# %%
#describe the age variable in inp1.

inp1.age.describe()
# Out:
# count    45161.000000
# mean        40.935763
# std         10.618790
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
#plot the histogram of age variable.

plt.figure(figsize = [10,6])
sns.set()
sns.histplot(data = inp1, x = 'age', bins = 30);


plt.hist(inp1.age);

# %%
#plot the boxplot of age variable.

# plt.figure(figsize = [10,6])
sns.set()
sns.boxplot(data = inp1, x = 'age');

sns.boxplot(inp1.age)

# yo box plot herda there isnt a big gap between the fence and the 1st point so its pretty muh continuous
# yeslai outliers vanna mildaina kinaki box plot herda testo tadha xainan points haru
# yiniharu simply higher values hun
# so yesma outliers chainan so nothing needs to be done

# So, in the above video, you have seen that the age variable has outliers, but these can be treated as the normal values
# of age because any person can be over 70 or 80 years of age. Also, the 70-90 age group is sparsely populated and participate
# in opening the term deposit account, which is why these set of people fall out of the box plot but they are not outliers and
# can be considered as normal values.
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# #### Salary variable

# %%
#describe the salary variable of inp1.

inp1.salary.describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
#plot the boxplot of salary variable.

plt.figure(figsize = [10,6])

sns.set()
sns.boxplot(data = inp1, x = 'salary');

# %% [markdown]
# #### Balance variable

# %%
#describe the balance variable of inp1.

inp1.balance.describe()

# -ve baance ni hun6 manche haruko so yo chai acceptable nai hola
# The mean is the average value of a dataset, while the median is the middle value when the data is arranged in
# ascending or descending order.
# yeha 50% ta median nai ho
# median ra 75% samma ma 3times jump cha vlaues
# the 75% ra max ko bich ma dherai nai cha gap almost close to 7 times so sankaaspad cha

# 25%: The first quartile or 25th percentile, which is 72.
# This means that 25% of the values in "balance" are less than or equal to 72.
# 50%: The second quartile or median, which is 448. 
# This means that 50% of the values in "balance" are less than or equal to 448.
# 75%: The third quartile or 75th percentile, which is 1,428.
# This means that 75% of the values in "balance" are less than or equal to 1,428.
# Out:
# count     45161.000000
# mean       1362.850690
# std        3045.939589
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
#plot the boxplot of balance variable.

# plt.figure(figsize=[8,2])
# sns.boxplot(data = inp1, x = 'balance')
sns.boxplot(inp1.balance)
plt.show()

# %%
#plot the boxplot of balance variable after scaling in 8:2.

# inp1.balance = inp1.balance.apply(lambda x: x*(8/2))
# sns.boxplot(inp1.balance);

# %%
#print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable

inp1.balance.quantile([0.5, 0.7, 0.9, 0.95, 0.99])
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.90     3576.0
# 0.95     5769.0
# 0.99    13173.4
# Name: balance, dtype: float64

# %%
inp1[inp1.balance>15000].describe()
# Out:
#               age         salary        balance         day    campaign  \
# count  351.000000     351.000000     351.000000  351.000000  351.000000
# mean    45.341880   70008.547009   24295.780627   16.022792    2.749288
# std     12.114333   34378.272805   12128.560693    8.101819    3.036886
# min     23.000000       0.000000   15030.000000    1.000000    1.000000
# 25%     35.000000   50000.000000   17074.000000    9.000000    1.000000
# 50%     44.000000   60000.000000   20723.000000   18.000000    2.000000
# 75%     55.000000  100000.000000   26254.000000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   62.000000  351.000000
# mean   188.516129    0.555556
# std    118.796388    1.784590
# min     31.000000    0.000000
# 25%     96.250000    0.000000
# 50%    167.500000    0.000000
# 75%    246.500000    0.000000
# max    589.000000   23.000000

# %%
# yo herda yo manche haru  paisawaal nai chan so yiniharule campaign accept garne chances badi hun6
# so yo values harulai hatauna mildaina
# so mean ko satta quantiles/percentile/median haru herne
# kinaki mean ta yo manche haruko ta high nai cha nita 24000 vanda badi
# so whenever we have to work with this variable 'balance' we will not be using mean 
# kinaki quantiles/percentile/median are not affected by outliers

# %% [markdown]
# ### Segment- 6, Standardising values

# %% [markdown]
# Checklist for data standardization exercises:
# - **Standardise units**: Ensure all observations under one variable are expressed in a common and consistent unit, e.g., convert lbs to kg, miles/hr to km/hr, etc.
# - **Scale values if required**: Make sure all the observations under one variable have a common scale.
# - **Standardise precision** for better presentation of data, e.g., change 4.5312341 kg to 4.53 kg.
# - **Remove extra characters** such as common prefixes/suffixes, leading/trailing/multiple spaces, etc. These are irrelevant to analysis.
# - **Standardise case**: String variables may take various casing styles, e.g., UPPERCASE, lowercase, Title Case, Sentence case, etc.
# - **Standardise format**: It is important to standardise the format of other elements such as date, name, etce.g., change 23/10/16 to 2016/10/23, “Modi, Narendra” to “Narendra Modi", etc.

# %%
# standardization of values

# aba cell level ma herne
# values that need to be corrected

# standardize numeric values:

# standardise units
# suppose from multipple data sources we get the data
# aba euta source ukko arko us ko
# euta ma footballers ko weihgt kg ma cha arko ma poundsma cha
# aba unit conversions garin6

# scale values where required
# sometimes we need to fit into a percentage scale
# like in case of 2 digester pressure range
# euta ko yetti hun6 arko ko yetti hun6
# aba duitako comparison garna scaling garin6 percentage ma 
# Make sure all the observations under one variable have a common scale.

# standardise precision
# jastai 380 mill vanyo vane range chai 370 mill ya 380 mill ya 390 mill
# 10 mill yeta uta hunasak6 
# uncertainty huda
# tara yadi 381mill ho vane
# ki 380 mill ya 381 mill ya 382 mill hunasak6
# mero height 5 ft 2 inch van6u
# 189878mmm vandina kailepani
# change 4.5312341 kg to 4.53 kg for better prresentation


# standardize texts:

# remove extra characters
# names can have common prefix
# places can have common prefix 
# yo gould get rid of that
# there might be multiple spaces between those so can get rid of those
# get rid of the leading spaces, trailing spaces
# lookups matches failed hun6 dherai jasto kinaki yo kuraharule garda
# so leading trailing ra multiple spaces in the middle lai get rid of them
# get rid of any common suffixes or prefixes that are there in the text

# standardize the casese
# convert everthing to lower case or upper case or sentence case
# keep it in the same case

# standardise format
# dd/mm/yy or mm/dd/yy
# fristname middlename lastname hun6
# J ramchandra cha re column ma
# first name extract garne ho vane J hun6
# yo ta vaena
# so J lai replca garne ramchandra ani extract garne 
# It is important to standardise the format of other elements such as date, name, etc.
# For example, change 23/10/16 to 2016/10/23, “Modi, Narendra” to “Narendra Modi", etc.

# %%
# Apart from standardizing the valus
# there is a need for fixing invaid values
# correct the type of the data
# numbers are stored as strings
# strings as numberes
# dates are stored as strings
# make sure you get it to the right time
# remember you want something as a number if you want to add it up
# if you want too group by it you want it just by text
# dates you always want as dates
# dates string ma vayo vane dates ma convert garne

# sometimes values will be there which will not make any sense
# Gender ma M ra F vako thik6 tara tyo bahek ko chai invalid ho
# pincode with 7 digits dont exist
# mobile no with 14 digits
# range vitra pare thik cha natra invalid like temperature range
# like value less than -273 degree C
# business ma chai sales ma katiwata vayo vanera -1units vayo vane -1 wata sales ta hunna
# return order vayo vane chai -1 hunasak6
# sales price -ve hunna
# number of years the employee has been working cant be greater than the employees age
# gross sales>netsales
# date of delivery>date of ordering

# if invalid value vayo vane treat it as a missing value, treat it as if it doesnt exist 
# and resolve it as if it was a missing value

# Encode unicode properly: In case the data is being read as junk characters, try to change the encoding,
#     for example, use CP1252 instead of UTF-8.

# Convert incorrect data types: Change the incorrect data types to the correct data types for ease of analysis.
#     For example, if numeric values are stored as strings, then it would not be possible to calculate metrics such as
#     mean, median, etc. Some of the common data type corrections include changing a string to a number ("12,300" to “12300”),
#     a string to a date ("2013-Aug" to “2013/08”), a number to a string (“PIN Code 110001” to "110001"), etc.

# Correct the values that lie beyond the range: If some values lie beyond the logical range, for example, temperature less than
#     -273° C (0° K), then you would need to correct those values as required. A close look at the data set would help you
#     determine whether there is scope for correction or the value needs to be removed.

# Correct the values not belonging in the list: Remove the values that do not belong to a list. For example, in a data set of
#     blood groups of individuals, strings ‘E’ or ‘F’ are invalid values and can be removed.

# Fix incorrect structure: Values that don’t follow a defined structure can be removed from a data set. For example, in a data
#     set containing the pin codes of Indian cities, a pin code of 12 digits would be an invalid value and would need to be
#     removed. Similarly, a phone number of 12 digits would be an invalid value.

# Validate internal rules: Internal rules, if present, should be correct and consistent. For example, the date of a product’s
#     delivery should definitely come after the date of purchase.

# %%
# Filter data

# Deduplicate data: Remove identical rows and the rows in which some columns are identical.

# Filter rows: Filter rows by segment and date period to obtain only rows relevant to the analysis.

# Filter columns: Filter columns relevant to the analysis.

# Aggregate data: Group by the required keys and aggregate the rest.

# %% [markdown]
# #### Duration variable

# %%
inp1.duration.dtype
# Out:
# dtype('O')

# %%
inp1.duration.head()
# Out:
# 0    261 sec
# 1    151 sec
# 2     76 sec
# 3     92 sec
# 4    198 sec
# Name: duration, dtype: object

# %%
#describe the duration variable of inp1

inp1.duration.describe()

# the top value is 1.5 min
# vanepaxi secs ma ni cha ra mins ma ni cha values
# aba sabailai secs ma lagne
# tesko lagi jun un min ma cha tiniharulai convert garne sec ma
# 1 min = 60 sec
# 1.5 min = 1.5*60 sec
# Out:
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object

# %%
inp1.dtypes
inp1.duration.dtype
inp1.duration[0][4:]
# Out:
# 'sec'

# %%
#convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.

inp1.duration  = inp1.duration.apply(lambda x: float(x.split(' ')[0])/60 if x.find('sec')>0 else float(x.split()[0]))
# inp1.duration = inp1.duration.apply(lambda x: float(x.split()[0])/60 if 'min' in x else float(x.split()[0]))
inp1.duration.describe()
# x.find('sec')>0 garda sec substring find gar6 tara 0 vanda mathiko indexma matrai find gar6 pare True natra false -1 din6
# Out:
# count    45161.000000
# mean         4.302774
# std          4.293129
# min          0.000000
# 25%          1.716667
# 50%          3.000000
# 75%          5.316667
# max         81.966667
# Name: duration, dtype: float64

# %%
#describe the duration variable

# 75% of the values are either 5.31 or less thatn 5.31

# %% [markdown]
# ## Session- 3, Univariate Analysis

# %% [markdown]
# ### Segment- 2, Categorical unordered univariate analysis

# %% [markdown]
# Unordered data do not have the notion of high-low, more-less etc. Example:
# - Type of loan taken by a person = home, personal, auto etc.
# - Organisation of a person = Sales, marketing, HR etc.
# - Job category of persone.
# - Marital status of any one.

# %% [markdown]
# #### Marital status

# %%
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month   duration  campaign  pdays  previous  \
# ...

# %%
inp1.dtypes

# we can see the numerical feature and the categorical feature
# Out:
# age          float64
# salary         int64
# balance        int64
# marital       object
# targeted      object
# default       object
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration     float64
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# response      object
# jobs          object
# education     object
# dtype: object

# %%
#calculate the percentage of each marital status category. 

inp1.marital.value_counts(normalize = True)
# Out:
# married     0.601957
# single      0.282943
# divorced    0.115099
# Name: marital, dtype: float64

# %%
inp1.marital.value_counts()
# Out:
# married     27185
# single      12778
# divorced     5198
# Name: marital, dtype: int64

# %%
inp1.marital.describe()
# Out:
# count       45161
# unique          3
# top       married
# freq        27185
# Name: marital, dtype: object

# %%
#plot the bar graph of percentage marital status categories

type(inp1.marital.value_counts(normalize = True))
plt.hist(inp1.marital);

# inp1.marital.value_counts(normalize = True).plot.barh()

# %%
# Univariate analysis involves the analysis of a single variable at a time. The concept of univariate analysis is divided into
# ordered and unordered category of variables. In this segment, you will learn how to conduct univariate analysis on categorical
# unordered variables. 

 

# Unordered data is the type of data that does not have any measurable terms (measurable terms can be like high-low, more-less,
# fail-pass, etc.) Example:

# The type of loan taken by an individual (home loan, personal loan, auto loan, etc.) does not have any ordered notion.
# They are just different types of loans.

# Departments of an organisation — Sales, Marketing, HR — are different departments in an organization, with no measurable
# attribute attached to any term.

 

# Unordered variables also called Nominal variables.

 

# An unordered variable, primarily, is a categorical variable that has no defined order. Let's consider the example of the job
# column in the Bank Marketing dataset. There, 'job' is divided into many sub-categories like technician, blue-collar, services,
# management, etc. There is no weight or measure given to any value in the 'job' column.

# %%
inp1.jobs.value_counts()
# Out:
# blue-collar      9722
# management       9451
# technician       7589
# admin.           5165
# services         4148
# retired          2262
# self-employed    1574
# entrepreneur     1484
# unemployed       1302
# housemaid        1238
# student           938
# unknown           288
# Name: jobs, dtype: int64

# %% [markdown]
# #### Job

# %%
#calculate the percentage of each job status category.

inp1.jobs.value_counts(normalize = True)
# Out:
# blue-collar      0.215274
# management       0.209273
# technician       0.168043
# admin.           0.114369
# services         0.091849
# retired          0.050087
# self-employed    0.034853
# entrepreneur     0.032860
# unemployed       0.028830
# housemaid        0.027413
# student          0.020770
# unknown          0.006377
# Name: jobs, dtype: float64

# %%
#plot the bar graph of percentage job categories

inp1.jobs.value_counts(normalize = True).plot.barh();

# %% [markdown]
# ### Segment- 3, Categorical ordered univariate analysis

# %% [markdown]
# Ordered variables have some kind of ordering. Some examples of bank marketing dataset are:
# - Age group= <30, 30-40, 40-50 and so on.
# - Month = Jan-Feb-Mar etc.
# - Education = primary, secondary and so on.

# %% [markdown]
# #### Education

# %%
#calculate the percentage of each education category.

inp1.education.value_counts(normalize = True)
# Out:
# secondary    0.513275
# tertiary     0.294192
# primary      0.151436
# unknown      0.041097
# Name: education, dtype: float64

# %%
#plot the pie chart of education categories

inp1.education.value_counts(normalize = True).plot.pie();

# %% [markdown]
# #### poutcome

# %%
#calculate the percentage of each poutcome category.

inp1.poutcome.value_counts(normalize = True)
# Out:
# unknown    0.817520
# failure    0.108368
# other      0.040721
# success    0.033392
# Name: poutcome, dtype: float64

# %%
inp1.poutcome.value_counts(normalize = True).plot.bar();

# %%
inp1[~(inp1.poutcome == 'unknown')].poutcome.value_counts()
# Out:
# failure    4894
# other      1839
# success    1508
# Name: poutcome, dtype: int64

# %%
inp1[~(inp1.poutcome == 'unknown')].poutcome.value_counts(normalize = True).plot.bar();

# %% [markdown]
# #### Response the target variable

# %%
#calculate the percentage of each response category.

inp1.response.value_counts(normalize = True)
# Out:
# no     0.882974
# yes    0.117026
# Name: response, dtype: float64

# %%
#plot the pie chart of response categories

inp1.response.value_counts(normalize = True).plot.pie();

# %%
# In bivariate analysis, when variables like marital status, job and education will be plotted with response variables,
# then you will be in a position to decide which categories in respective columns have the highest chances of a positive reply.

# %% [markdown]
# ## Session- 4, Bivariate and Multivariate Analysis

# %%
# Anand mentioned that you can treat numeric variables as ordered categorical variables. For analysis, 
# you can deliberately convert the numeric variables into ordered categorical; for example, if you have the incomes of a
# few thousand people, which range from $5,000 to $1,00,000, then you can categorise them into bins such as
# [5000, 10000], [10000,15000] and [15000, 20000].

# This is called 'binning'. 

# Now, which of the following variables can be binned into ordered categorical variables? Mark all correct options.

# The temperature for a city over a certain period of time.

# Feedback:
# You can bin the temperatures as [0, 10 degrees], [10, 20 degrees], etc

# The revenue generated by a company per day.

# Feedback:
# This can also be binned, e.g., [0, 10k], [10k, 20k], etc.
# You can bin the temperatures as [0, 10 degrees], [10, 20 degrees], etc.
# This can also be binned, e.g., [0, 10k], [10k, 20k], etc.

# %%
# kun bela mean use garne kun bela median use garme?

# suppose 10 jana chan re room ma bill gates(outlier) enter garyo re
# aba salaries average nikalne ho vane sab ko sal ko sum divided by 10 hun6
# ani kun mancheko kati distributon thaha hun6
# so yo garne vae chai mean use garne

# tara tei scenario ma yadi typical employee ko kati salary cha thapauna chai median use garne
# aba outliers haru lai naline
# sabailai ascending orderma rakhne ani sabse bich ko mancheko salary k ho patta laune
# ani tei le nai represent gar6 sabaiko

# as a rule of thumb use median rather than mean
# if using mean look into it more

# outlier le mean lai influence gar6 but medianlai asar gardaina.

# Mean > Median> Mode

# The mode value is the lowest among the three parameters because this value has the highest frequency.
# Median should lie between the mean and mode.
# Since mean is affected by outliers, variance and standard deviation will also be affected by outliers.

# 100/2 = 50%
# 50ko left ma (50+0)/2 = 25%
# 50 ko right ma (50+100)/2 = 75%

# aba variance vaneko/inter quartile range Q1(25%) ra Q2(75%) kati spread cha vanera thapauna best ho standard deviation haina
# std use garda outlier le dherai nai asar gar6 so std as a measure of data spread use nagarne

# suppose class 8A ma 25% ktaharu ko height ra 75% kta haruko height ma dherai farak cha vane maile team form garda randomly
# chan ni hun6 koko team ma rakhne vanera
# yadi tara 8B ma 25% ra 75% bich ma dherai differrence xaina vane chai  maile randomly channa mildaina

# %% [markdown]
# ### Segment-2, Numeric- numeric analysis

# %% [markdown]
# There are three ways to analyse the numeric- numeric data types simultaneously.
# - **Scatter plot**: describes the pattern that how one variable is varying with other variable.
# - **Correlation matrix**: to describe the linearity of two numeric variables.
# - **Pair plot**: group of scatter plots of all numeric variables in the data frame.

# %%
# kinds of analysis in bivariate analysis:
# Analysis Between Two Numeric Variables
# Analysis Between Numeric and Categorical Variables
# Correlation Versus Causation
# Analysis Between Two Categorical Variables
# Multivariate Analysis

# %%
# num vs num:
#     correleation marix
#     scatter plot
#     pairplot
#plot the scatter plot of balance and salary variable in inp1

# tara dherai numerical variable huda kati matrai banaune plots
# supposeyou have 10 numerical variable so testo bela hamile dherai 10 c2 scatter plots banaunu vanda correleationmatrix use garne
# ani the cell value will be the coreleation between two numerical variables
# pairplot le ni hunna
# correlation matraix banaerai garnupar6 dherai numerical variables vako casema

# %%
#plot the scatter plot of balance and age variable in inp1

plt.scatter(inp1 ['age'], inp1['balance']);

# %%
plt.scatter(inp1 ['salary'], inp1['balance']);

# %%
#plot the pair plot of salary, balance and age in inp1 dataframe.

sns.pairplot(data = inp1, vars = ['age', 'balance', 'salary']);

# %%
# Now, refer to the image below and observe how there is no correlation between these variables.

# %% [markdown]
# #### Correlation heat map

# %%
#plot the correlation matrix of salary, balance and age in inp1 dataframe.

inp1[['age', 'salary', 'balance']].corr()

# yesma herda balance ra salary ma herda high correlation cha but plot ma dekhindaina
# there may be cases where a high correlation coefficient between two variables but there is no relation between them.
# Out:
#               age    salary   balance
# age      1.000000  0.024513  0.097710
# salary   0.024513  1.000000  0.055489
# balance  0.097710  0.055489  1.000000

# %%
inp1[['age', 'salary', 'balance']].corr() # grid
# Out:
#               age    salary   balance
# age      1.000000  0.024513  0.097710
# salary   0.024513  1.000000  0.055489
# balance  0.097710  0.055489  1.000000

# %%
# sns.heatmap(grid we want to plot, annot = True, cmap = 'Reds')
sns.heatmap(inp1[['age', 'salary', 'balance']].corr(), annot = True, cmap = 'Reds');

# %%
# so individual variables use garda scatterplot use garne
# ali badi combinations huda pairplot garne
# ra a lot f features cha ra we need to have a good quick glimpse at it then we do a correleation matrix grid and a heatmap

# %% [markdown]
# ![Screenshot%20%281993%29.png](attachment:Screenshot%20%281993%29.png)

# %% [markdown]
# ![Screenshot%20%281994%29.png](attachment:Screenshot%20%281994%29.png)

# %% [markdown]
# ![Screenshot%20%281995%29.png](attachment:Screenshot%20%281995%29.png)

# %%
# correlation vs causation
# duita numerical values ko bichma strong correlation vaepani causation hun6 vanne hunna
# vannale eutale garda arko ma asar garne

# %% [markdown]
# ![Screenshot%20%281996%29.png](attachment:Screenshot%20%281996%29.png)

# %% [markdown]
# ### Segment- 4, Numerical categorical variable

# %% [markdown]
# #### Salary vs response

# %%
#groupby the response to find the mean of the salary with response no & yes seperatly.

inp1.groupby('response')['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
#groupby the response to find the median of the salary with response no & yes seperatly.

inp1.groupby('response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
#plot the box plot of salary for yes & no responses.

sns.boxplot(data = inp1, x = inp1.response, y = inp1.salary);

# %% [markdown]
# #### Balance vs response

# %%
#plot the box plot of balance for yes & no responses.

sns.boxplot(data = inp1, x = inp1.response, y = inp1.balance);

# because of a high concentration of data and or because of higher values in the data set, for example, the balance variable.

# %%
# hamilai agadibatai thaacha ki balance ma thulo values haru chan so yo values harule box plot ko visual lai unclear banaidin6

# %%
#groupby the response to find the mean of the balance with response no & yes seperatly.

inp1.groupby('response')['balance'].mean()
# hamilai tha cha ki balance ko outliers ra thulo values harule asar gar6 meanlai
# Out:
# response
# no     1304.292281
# yes    1804.681362
# Name: balance, dtype: float64

# %%
#groupby the response to find the median of the balance with response no & yes seperatly.

inp1.groupby('response')['balance'].median()
# medianlai outliers harule asar gardaina
# Out:
# response
# no     417.0
# yes    733.0
# Name: balance, dtype: float64

# %% [markdown]
# ##### 75th percentile

# %%
#function to find the 75th percentile.
def p75(x):
    return np.quantile(x, 0.75)

# %%
#calculate the mean, median and 75th percentile of balance with response

inp1.groupby('response')['balance'].aggregate(['mean', 'median', p75])

# balance variable ko nature le garda box plotma insight nikalna mildaina so hamile mean median ra quantile sabai nikalchau
# Out:
#                  mean  median     p75
# response
# no        1304.292281   417.0  1345.0
# yes       1804.681362   733.0  2159.0

# %%
#plot the bar graph of balance's mean an median with response.

inp1.groupby('response')['balance'].aggregate(['mean', 'median']).plot.bar()
# Out:
# <AxesSubplot:xlabel='response'>

# %% [markdown]
# #### Education vs salary

# %%
#groupby the education to find the mean of the salary education category.

inp1.groupby('education')['salary'].mean()
# Out:
# education
# primary      34232.343910
# secondary    49731.449525
# tertiary     82880.249887
# unknown      46529.633621
# Name: salary, dtype: float64

# %%
#groupby the education to find the median of the salary for each education category.

inp1.groupby('education')['salary'].median()
# Out:
# education
# primary       20000.0
# secondary     55000.0
# tertiary     100000.0
# unknown       50000.0
# Name: salary, dtype: float64

# %% [markdown]
# #### Job vs salary

# %%
#groupby the job to find the mean of the salary for each job category.

inp1.groupby('jobs')['salary'].mean()
# Out:
# jobs
# admin.            50000.0
# blue-collar       20000.0
# entrepreneur     120000.0
# housemaid         16000.0
# management       100000.0
# retired           55000.0
# self-employed     60000.0
# services          70000.0
# student            4000.0
# technician        60000.0
# unemployed         8000.0
# unknown               0.0
# Name: salary, dtype: float64

# %% [markdown]
# ### Segment- 5, Categorical categorical variable

# %%
#create response_flag of numerical data type where response "yes"= 1, "no"= 0

# yesma k garne vane cat-cat relation dekhauna euta cat variable lai numerical col ma convert garne ani tesko mean nikalne groupby garera

# response vaneko cat col ho junma yes no cha teslai hamile 1 0 ma lagna mil6

# ani arko cat col sanga goup by garda tesko avg/median/quantile nikalda hun6

inp1['response_flag'] = np.where(inp1['response'] == 'yes' , 1, 0)
inp1
inp1['response_flag'].value_counts(normalize = True)
# Out:
# 0    0.882974
# 1    0.117026
# Name: response_flag, dtype: float64

# %% [markdown]
# #### Education vs response rate

# %%
#calculate the mean of response_flag with different education categories.

inp1.groupby('education')['response_flag'].mean()
# Out:
# education
# primary      0.086416
# secondary    0.105608
# tertiary     0.150083
# unknown      0.135776
# Name: response_flag, dtype: float64

# %% [markdown]
# #### Marital vs response rate

# %%
#calculate the mean of response_flag with different marital status categories.

inp1.groupby('marital')['response_flag'].mean()
# Out:
# marital
# divorced    0.119469
# married     0.101269
# single      0.149554
# Name: response_flag, dtype: float64

# %%
#plot the bar graph of marital status with average value of response_flag

inp1.groupby('marital')[['response_flag']].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='marital'>

# %% [markdown]
# #### Loans vs response rate

# %%
#plot the bar graph of personal loan status with average value of response_flag

inp1.groupby('loan')['response_flag'].mean()
# Out:
# loan
# no     0.126569
# yes    0.066953
# Name: response_flag, dtype: float64

# %% [markdown]
# #### Housing loans vs response rate

# %%
#plot the bar graph of housing loan status with average value of response_flag

inp1.groupby('housing')['response_flag'].mean().plot.bar();

# %% [markdown]
# #### Age vs response

# %%
#plot the boxplot of age with response_flag

sns.boxplot(data = inp1, x = inp1.age, y = inp1.response);

# %%
# creating age buckets
# by using cut

# ?pd.cut

# %% [markdown]
# ##### making buckets from age columns

# %%
#create the buckets of <30, 30-40, 40-50 50-60 and 60+ from age column.

inp1['age_group'] = pd.cut(inp1.age, bins= [0, 20, 40, 60, 9999], labels = ['0-20', '20-40', '40-60', '60+'])
inp1['age_group'].value_counts()
inp1['age_group'].value_counts(normalize = True)
inp1.head()

# %%
#plot the percentage of each buckets and average values of response_flag in each buckets. plot in subplots.

plt.figure(figsize = [10, 4])

plt.subplot(1, 2, 1)
inp1.age_group.value_counts(normalize = True).plot.bar()

plt.subplot(1,2,2)
inp1.groupby('age_group')['response_flag'].mean().plot.bar()

# %%
#plot the bar graph of job categories with response_flag mean value.

inp1.groupby('jobs')['response_flag'].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='jobs'>

# %% [markdown]
# ### Segment-6, Multivariate analysis

# %% [markdown]
# #### Education vs marital vs response

# %%
inp1.age
# Out:
# 0        58.0
# 1        44.0
# 2        33.0
# 3        47.0
# 4        33.0
#          ...
# 45206    51.0
# 45207    71.0
# 45208    72.0
# 45209    57.0
# 45210    37.0
# Name: age, Length: 45161, dtype: float64

# %%
#create heat map of education vs marital vs response_flag

res = pd.pivot_table(inp1 , index = 'education', columns = 'marital' , values = 'response_flag') # this gives a grid
res
# Out:
# marital    divorced   married    single
# education
# primary    0.138852  0.075601  0.106808
# secondary  0.103559  0.094650  0.129271
# tertiary   0.137415  0.129835  0.183737
# unknown    0.142012  0.122519  0.162879

# %% [markdown]
# #### Job vs marital vs response

# %%
res = pd.pivot_table(inp1, index = 'jobs', columns = 'marital', values = 'response_flag')
res
# Out:
# marital        divorced   married    single
# jobs
# admin.         0.120160  0.113383  0.136153
# blue-collar    0.077644  0.062778  0.105760
# entrepreneur   0.083799  0.075843  0.113924
# housemaid      0.097826  0.072527  0.166667
# management     0.127928  0.126228  0.162254
# retired        0.283688  0.220682  0.120370
# self-employed  0.158273  0.079637  0.191874
# services       0.091241  0.074105  0.117696
# student        0.166667  0.185185  0.293850
# technician     0.083243  0.102767  0.132645
# unemployed     0.157895  0.132695  0.195000
# unknown        0.058824  0.103448  0.176471

# %%
#create the heat map of Job vs marital vs response_flag.

# hamilai thaha cha ki overall response rate vaneko kati % le yes vane jun 0.117 ho
# center dida tesko reference ma color gardin6 banaidin6
sns.heatmap(res, cmap = 'RdYlGn', annot = True, center = 0.117);

# %% [markdown]
# #### Education vs poutcome vs response

# %%
#create the heat map of education vs poutcome vs response_flag.

res = pd.pivot_table(inp1, index = 'education', columns = 'poutcome', values = 'response_flag')
res
# Out:
# poutcome    failure     other   success   unknown
# education
# primary    0.088785  0.143443  0.609023  0.071821
# secondary  0.109007  0.140831  0.641902  0.084244
# tertiary   0.168683  0.220994  0.657005  0.114256
# unknown    0.158192  0.200000  0.679012  0.101761

# %%
sns.heatmap(res, cmap = 'RdYlGn', annot = True, center = 0.117 );

# %%
inp1[inp1.pdays>0].response_flag.mean()
# Out:
# 0.2307785593014795

# %%
sns.heatmap(res, cmap = 'RdYlGn', annot = True, center = 0.23 );
